# %% [markdown]
# # PANDAS introduction

# %% [markdown]
# pandas is a python module that makes data science easy and effective. It is used for data organizing and data cleaning/data munging/data wrangling.

# %%
import pandas as pd
df = pd.read_csv("C:\PYTHONcodes\DATA_SCIENCE\pandas\datasets_1655_4420_weather_data_nyc_centralpark_2016(1).csv")
df
# Out:
#            date  maximum temperature  minimum temperature  \
# 0      1-1-2016                   42                   34
# 1      2-1-2016                   40                   32
# 2      3-1-2016                   45                   35
# 3      4-1-2016                   36                   14
# 4      5-1-2016                   29                   11
# 5      6-1-2016                   41                   25
# 6      7-1-2016                   46                   31
# 7      8-1-2016                   46                   31
# 8      9-1-2016                   47                   40
# 9     10-1-2016                   59                   40
# 10    11-1-2016                   40                   26
# 11    12-1-2016                   44                   25
# 12    13-1-2016                   30                   22
# 13    14-1-2016                   38                   22
# 14    15-1-2016                   51                   34
# ...

# %%
df['precipitation'].max()
# Out:
# 'T'

# %%
max=df['average temperature'].max()

# %% [markdown]
# #### to know the day that had the maximum temperature

# %%
df['date'][df['average temperature']==max]
# Out:
# 225    13-8-2016
# Name: date, dtype: object

# %% [markdown]
# FIND THE AVERAGE

# %%
df['average temperature'].mean()
# Out:
# 57.21584699453552

# %% [markdown]
# ##### data cleaning/data munging/data wrangling

# %%
df.fillna(0, inplace=True)
df['precipitation'].max()
# Out:
# 'T'
